# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import networkx as nx

# %%
df = pd.read_excel('/Users/kevintruong/Downloads/california_housing_data.xlsx')
latitude = pd.read_excel ('/Users/kevintruong/Downloads/california_housing_data.xlsx', usecols="H")
longtitude = pd.read_excel ('/Users/kevintruong/Downloads/california_housing_data.xlsx', usecols="I")
print(longtitude,latitude)

# %%
x_coords = [latitude]
y_coords = [longtitude]
plt.scatter(x_coords, y_coords, color='blue')
